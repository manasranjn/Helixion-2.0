# %%
import pandas as pd
df = pd.read_csv('customers-100.csv')
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda       NaN
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                               NaN  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# 95                        Carey LLC       East Richard
# 96            Ware, Burns and Oneal       New Bradview
# 97                    Schmitt-Jones         Ortegaland
# 98               Fitzgerald-Harrell    Lake Elijahview
# 99               Le, Nash and Cross          Judymouth
#
#                        Country                 Phone 1  \
# 0                        Chile            229.077.5154
# 1                     Djibouti              5153435776
# 2                          NaN                   -1199
# 3           Dominican Republic  001-808-617-6467x12895
# 4   Slovakia (Slovak Republic)  001-234-203-0635x76146
# ..                         ...                     ...
# 95                      Guyana     (188)169-1674x58692
# 96                   Sri Lanka                   -3769
# 97             Solomon Islands    +1-753-067-8419x7170
# 98                       Aruba           (530)311-9786
# 99                    Honduras           (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 0         397.884.0519x718        zunigavanessa@smith.info        24-08-2020
# 1         686-620-1820x944                 vmata@colon.com        23-04-2021
# 2      (496)978-3969x58947             beckycarr@hogan.com        25-03-2020
# 3                    -9892     stanleyblackwell@benson.org        02-06-2020
# 4    001-199-446-3860x3486         colinalvarado@miles.net        17-04-2021
# ..                     ...                             ...               ...
# 95    001-841-293-3519x614                hhart@jensen.com        30-01-2022
# 96            605.413.3198               vkemp@ferrell.com        10-07-2021
# 97   +1-632-666-7507x92121                swagner@kane.org        18-09-2021
# 98  001-869-452-0943x12424  mccarthystephen@horn-green.biz        11-08-2021
# 99            783.639.1472          colleen91@faulkner.biz        11-03-2020
#
#                               Website
# 0          http://www.stephenson.com/
# 1               http://www.hobbs.com/
# 2            http://www.lawrence.com/
# 3          http://www.good-lyons.com/
# 4         https://goodwin-ingram.com/
# ..                                ...
# 95            http://hayes-perez.com/
# 96         https://novak-allison.com/
# 97              https://www.ross.com/
# 98               http://watkins.info/
# 99  http://www.hatfield-saunders.net/
#
# [100 rows x 12 columns]

# %%
type(df['Subscription Date'][0])
# Out:
# str

# %%
df = pd.read_csv('customers-100.csv', parse_dates=['Subscription Date'])
type(df['Subscription Date'][0])
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_5348\149584795.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv('customers-100.csv', parse_dates=['Subscription Date'])
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index('Index', inplace=True)
df
# Out:
#            Customer Id First Name Last Name                          Company  \
# Index
# 1      DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 2      1Ef7b82A4CAAD10    Preston    Lozano                              NaN
# 3      6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 4      5Cef8BFA16c5e3c      Linda       NaN  Dominguez, Mcmillan and Donovan
# 5      053d585Ab6b3159     Joanna    Bender         Martin, Lang and Andrade
# ...                ...        ...       ...                              ...
# 96     cb8E23e48d22Eae       Karl     Greer                        Carey LLC
# 97     CeD220bdAaCfaDf       Lynn  Atkinson            Ware, Burns and Oneal
# 98     28CDbC0dFe4b1Db       Fred    Guerra                    Schmitt-Jones
# 99     c23d1D9EE8DEB0A     Yvonne    Farmer               Fitzgerald-Harrell
# 100    2354a0E336A91A1   Clarence    Haynes               Le, Nash and Cross
#
#                     City                     Country                 Phone 1  \
# Index
# 1           East Leonard                       Chile            229.077.5154
# 2      East Jimmychester                    Djibouti              5153435776
# 3          Isabelborough                         NaN                   -1199
# 4             Bensonview          Dominican Republic  001-808-617-6467x12895
# 5         West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
# ...                  ...                         ...                     ...
# 96          East Richard                      Guyana     (188)169-1674x58692
# 97          New Bradview                   Sri Lanka                   -3769
# 98            Ortegaland             Solomon Islands    +1-753-067-8419x7170
# 99       Lake Elijahview                       Aruba           (530)311-9786
# 100            Judymouth                    Honduras           (753)813-6941
#
#                       Phone 2                           Email  \
# Index
# 1            397.884.0519x718        zunigavanessa@smith.info
# 2            686-620-1820x944                 vmata@colon.com
# 3         (496)978-3969x58947             beckycarr@hogan.com
# 4                       -9892     stanleyblackwell@benson.org
# 5       001-199-446-3860x3486         colinalvarado@miles.net
# ...                       ...                             ...
# 96       001-841-293-3519x614                hhart@jensen.com
# 97               605.413.3198               vkemp@ferrell.com
# 98      +1-632-666-7507x92121                swagner@kane.org
# 99     001-869-452-0943x12424  mccarthystephen@horn-green.biz
# 100              783.639.1472          colleen91@faulkner.biz
#
#       Subscription Date                            Website
# Index
# 1            2020-08-24         http://www.stephenson.com/
# 2            2021-04-23              http://www.hobbs.com/
# 3            2020-03-25           http://www.lawrence.com/
# 4            2020-06-02         http://www.good-lyons.com/
# 5            2021-04-17        https://goodwin-ingram.com/
# ...                 ...                                ...
# 96           2022-01-30            http://hayes-perez.com/
# 97           2021-07-10         https://novak-allison.com/
# 98           2021-09-18              https://www.ross.com/
# 99           2021-08-11               http://watkins.info/
# 100          2020-03-11  http://www.hatfield-saunders.net/
#
# [100 rows x 11 columns]

# %%
df
# Out:
#            Customer Id First Name Last Name                          Company  \
# Index
# 1      DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 2      1Ef7b82A4CAAD10    Preston    Lozano                              NaN
# 3      6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 4      5Cef8BFA16c5e3c      Linda       NaN  Dominguez, Mcmillan and Donovan
# 5      053d585Ab6b3159     Joanna    Bender         Martin, Lang and Andrade
# ...                ...        ...       ...                              ...
# 96     cb8E23e48d22Eae       Karl     Greer                        Carey LLC
# 97     CeD220bdAaCfaDf       Lynn  Atkinson            Ware, Burns and Oneal
# 98     28CDbC0dFe4b1Db       Fred    Guerra                    Schmitt-Jones
# 99     c23d1D9EE8DEB0A     Yvonne    Farmer               Fitzgerald-Harrell
# 100    2354a0E336A91A1   Clarence    Haynes               Le, Nash and Cross
#
#                     City                     Country                 Phone 1  \
# Index
# 1           East Leonard                       Chile            229.077.5154
# 2      East Jimmychester                    Djibouti              5153435776
# 3          Isabelborough                         NaN                   -1199
# 4             Bensonview          Dominican Republic  001-808-617-6467x12895
# 5         West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
# ...                  ...                         ...                     ...
# 96          East Richard                      Guyana     (188)169-1674x58692
# 97          New Bradview                   Sri Lanka                   -3769
# 98            Ortegaland             Solomon Islands    +1-753-067-8419x7170
# 99       Lake Elijahview                       Aruba           (530)311-9786
# 100            Judymouth                    Honduras           (753)813-6941
#
#                       Phone 2                           Email  \
# Index
# 1            397.884.0519x718        zunigavanessa@smith.info
# 2            686-620-1820x944                 vmata@colon.com
# 3         (496)978-3969x58947             beckycarr@hogan.com
# 4                       -9892     stanleyblackwell@benson.org
# 5       001-199-446-3860x3486         colinalvarado@miles.net
# ...                       ...                             ...
# 96       001-841-293-3519x614                hhart@jensen.com
# 97               605.413.3198               vkemp@ferrell.com
# 98      +1-632-666-7507x92121                swagner@kane.org
# 99     001-869-452-0943x12424  mccarthystephen@horn-green.biz
# 100              783.639.1472          colleen91@faulkner.biz
#
#       Subscription Date                            Website
# Index
# 1            2020-08-24         http://www.stephenson.com/
# 2            2021-04-23              http://www.hobbs.com/
# 3            2020-03-25           http://www.lawrence.com/
# 4            2020-06-02         http://www.good-lyons.com/
# 5            2021-04-17        https://goodwin-ingram.com/
# ...                 ...                                ...
# 96           2022-01-30            http://hayes-perez.com/
# 97           2021-07-10         https://novak-allison.com/
# 98           2021-09-18              https://www.ross.com/
# 99           2021-08-11               http://watkins.info/
# 100          2020-03-11  http://www.hatfield-saunders.net/
#
# [100 rows x 11 columns]

# %%
df2 = df.fillna("No Data")
df2
# Out:
#            Customer Id First Name Last Name                          Company  \
# Index
# 1      DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 2      1Ef7b82A4CAAD10    Preston    Lozano                          No Data
# 3      6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 4      5Cef8BFA16c5e3c      Linda   No Data  Dominguez, Mcmillan and Donovan
# 5      053d585Ab6b3159     Joanna    Bender         Martin, Lang and Andrade
# ...                ...        ...       ...                              ...
# 96     cb8E23e48d22Eae       Karl     Greer                        Carey LLC
# 97     CeD220bdAaCfaDf       Lynn  Atkinson            Ware, Burns and Oneal
# 98     28CDbC0dFe4b1Db       Fred    Guerra                    Schmitt-Jones
# 99     c23d1D9EE8DEB0A     Yvonne    Farmer               Fitzgerald-Harrell
# 100    2354a0E336A91A1   Clarence    Haynes               Le, Nash and Cross
#
#                     City                     Country                 Phone 1  \
# Index
# 1           East Leonard                       Chile            229.077.5154
# 2      East Jimmychester                    Djibouti              5153435776
# 3          Isabelborough                     No Data                   -1199
# 4             Bensonview          Dominican Republic  001-808-617-6467x12895
# 5         West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
# ...                  ...                         ...                     ...
# 96          East Richard                      Guyana     (188)169-1674x58692
# 97          New Bradview                   Sri Lanka                   -3769
# 98            Ortegaland             Solomon Islands    +1-753-067-8419x7170
# 99       Lake Elijahview                       Aruba           (530)311-9786
# 100            Judymouth                    Honduras           (753)813-6941
#
#                       Phone 2                           Email  \
# Index
# 1            397.884.0519x718        zunigavanessa@smith.info
# 2            686-620-1820x944                 vmata@colon.com
# 3         (496)978-3969x58947             beckycarr@hogan.com
# 4                       -9892     stanleyblackwell@benson.org
# 5       001-199-446-3860x3486         colinalvarado@miles.net
# ...                       ...                             ...
# 96       001-841-293-3519x614                hhart@jensen.com
# 97               605.413.3198               vkemp@ferrell.com
# 98      +1-632-666-7507x92121                swagner@kane.org
# 99     001-869-452-0943x12424  mccarthystephen@horn-green.biz
# 100              783.639.1472          colleen91@faulkner.biz
#
#       Subscription Date                            Website
# Index
# 1            2020-08-24         http://www.stephenson.com/
# 2            2021-04-23              http://www.hobbs.com/
# 3            2020-03-25           http://www.lawrence.com/
# 4            2020-06-02         http://www.good-lyons.com/
# 5            2021-04-17        https://goodwin-ingram.com/
# ...                 ...                                ...
# 96           2022-01-30            http://hayes-perez.com/
# 97           2021-07-10         https://novak-allison.com/
# 98           2021-09-18              https://www.ross.com/
# 99           2021-08-11               http://watkins.info/
# 100          2020-03-11  http://www.hatfield-saunders.net/
#
# [100 rows x 11 columns]

# %%
df3 = df.fillna({
    'Last Name': "No Last name",
    'Company': "No Company",
    'Country': "No Country"
})
df3
# Out:
#            Customer Id First Name     Last Name  \
# Index
# 1      DD37Cf93aecA6Dc     Sheryl        Baxter
# 2      1Ef7b82A4CAAD10    Preston        Lozano
# 3      6F94879bDAfE5a6        Roy         Berry
# 4      5Cef8BFA16c5e3c      Linda  No Last name
# 5      053d585Ab6b3159     Joanna        Bender
# ...                ...        ...           ...
# 96     cb8E23e48d22Eae       Karl         Greer
# 97     CeD220bdAaCfaDf       Lynn      Atkinson
# 98     28CDbC0dFe4b1Db       Fred        Guerra
# 99     c23d1D9EE8DEB0A     Yvonne        Farmer
# 100    2354a0E336A91A1   Clarence        Haynes
#
#                                Company               City  \
# Index
# 1                      Rasmussen Group       East Leonard
# 2                           No Company  East Jimmychester
# 3                        Murillo-Perry      Isabelborough
# 4      Dominguez, Mcmillan and Donovan         Bensonview
# 5             Martin, Lang and Andrade     West Priscilla
# ...                                ...                ...
# 96                           Carey LLC       East Richard
# 97               Ware, Burns and Oneal       New Bradview
# 98                       Schmitt-Jones         Ortegaland
# 99                  Fitzgerald-Harrell    Lake Elijahview
# 100                 Le, Nash and Cross          Judymouth
#
#                           Country                 Phone 1  \
# Index
# 1                           Chile            229.077.5154
# 2                        Djibouti              5153435776
# 3                      No Country                   -1199
# 4              Dominican Republic  001-808-617-6467x12895
# 5      Slovakia (Slovak Republic)  001-234-203-0635x76146
# ...                           ...                     ...
# 96                         Guyana     (188)169-1674x58692
# 97                      Sri Lanka                   -3769
# 98                Solomon Islands    +1-753-067-8419x7170
# 99                          Aruba           (530)311-9786
# 100                      Honduras           (753)813-6941
#
#                       Phone 2                           Email  \
# Index
# 1            397.884.0519x718        zunigavanessa@smith.info
# 2            686-620-1820x944                 vmata@colon.com
# 3         (496)978-3969x58947             beckycarr@hogan.com
# 4                       -9892     stanleyblackwell@benson.org
# 5       001-199-446-3860x3486         colinalvarado@miles.net
# ...                       ...                             ...
# 96       001-841-293-3519x614                hhart@jensen.com
# 97               605.413.3198               vkemp@ferrell.com
# 98      +1-632-666-7507x92121                swagner@kane.org
# 99     001-869-452-0943x12424  mccarthystephen@horn-green.biz
# 100              783.639.1472          colleen91@faulkner.biz
#
#       Subscription Date                            Website
# Index
# 1            2020-08-24         http://www.stephenson.com/
# 2            2021-04-23              http://www.hobbs.com/
# 3            2020-03-25           http://www.lawrence.com/
# 4            2020-06-02         http://www.good-lyons.com/
# 5            2021-04-17        https://goodwin-ingram.com/
# ...                 ...                                ...
# 96           2022-01-30            http://hayes-perez.com/
# 97           2021-07-10         https://novak-allison.com/
# 98           2021-09-18              https://www.ross.com/
# 99           2021-08-11               http://watkins.info/
# 100          2020-03-11  http://www.hatfield-saunders.net/
#
# [100 rows x 11 columns]

# %%
df4 = df.fillna(method='ffill')
df4
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_5348\195474103.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df4 = df.fillna(method='ffill')
#            Customer Id First Name Last Name                          Company  \
# Index
# 1      DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 2      1Ef7b82A4CAAD10    Preston    Lozano                  Rasmussen Group
# 3      6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 4      5Cef8BFA16c5e3c      Linda     Berry  Dominguez, Mcmillan and Donovan
# 5      053d585Ab6b3159     Joanna    Bender         Martin, Lang and Andrade
# ...                ...        ...       ...                              ...
# 96     cb8E23e48d22Eae       Karl     Greer                        Carey LLC
# 97     CeD220bdAaCfaDf       Lynn  Atkinson            Ware, Burns and Oneal
# 98     28CDbC0dFe4b1Db       Fred    Guerra                    Schmitt-Jones
# 99     c23d1D9EE8DEB0A     Yvonne    Farmer               Fitzgerald-Harrell
# 100    2354a0E336A91A1   Clarence    Haynes               Le, Nash and Cross
#
#                     City                     Country                 Phone 1  \
# Index
# 1           East Leonard                       Chile            229.077.5154
# 2      East Jimmychester                    Djibouti              5153435776
# 3          Isabelborough                    Djibouti                   -1199
# 4             Bensonview          Dominican Republic  001-808-617-6467x12895
# 5         West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
# ...                  ...                         ...                     ...
# 96          East Richard                      Guyana     (188)169-1674x58692
# 97          New Bradview                   Sri Lanka                   -3769
# 98            Ortegaland             Solomon Islands    +1-753-067-8419x7170
# 99       Lake Elijahview                       Aruba           (530)311-9786
# 100            Judymouth                    Honduras           (753)813-6941
#
#                       Phone 2                           Email  \
# Index
# 1            397.884.0519x718        zunigavanessa@smith.info
# 2            686-620-1820x944                 vmata@colon.com
# 3         (496)978-3969x58947             beckycarr@hogan.com
# 4                       -9892     stanleyblackwell@benson.org
# 5       001-199-446-3860x3486         colinalvarado@miles.net
# ...                       ...                             ...
# 96       001-841-293-3519x614                hhart@jensen.com
# 97               605.413.3198               vkemp@ferrell.com
# 98      +1-632-666-7507x92121                swagner@kane.org
# 99     001-869-452-0943x12424  mccarthystephen@horn-green.biz
# 100              783.639.1472          colleen91@faulkner.biz
#
#       Subscription Date                            Website
# Index
# 1            2020-08-24         http://www.stephenson.com/
# 2            2021-04-23              http://www.hobbs.com/
# 3            2020-03-25           http://www.lawrence.com/
# 4            2020-06-02         http://www.good-lyons.com/
# 5            2021-04-17        https://goodwin-ingram.com/
# ...                 ...                                ...
# 96           2022-01-30            http://hayes-perez.com/
# 97           2021-07-10         https://novak-allison.com/
# 98           2021-09-18              https://www.ross.com/
# 99           2021-08-11               http://watkins.info/
# 100          2020-03-11  http://www.hatfield-saunders.net/
#
# [100 rows x 11 columns]

# %%
df5 = df.fillna(method='bfill')
df5
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_5348\2285968968.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df5 = df.fillna(method='bfill')
#            Customer Id First Name Last Name                          Company  \
# Index
# 1      DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 2      1Ef7b82A4CAAD10    Preston    Lozano                    Murillo-Perry
# 3      6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 4      5Cef8BFA16c5e3c      Linda    Bender  Dominguez, Mcmillan and Donovan
# 5      053d585Ab6b3159     Joanna    Bender         Martin, Lang and Andrade
# ...                ...        ...       ...                              ...
# 96     cb8E23e48d22Eae       Karl     Greer                        Carey LLC
# 97     CeD220bdAaCfaDf       Lynn  Atkinson            Ware, Burns and Oneal
# 98     28CDbC0dFe4b1Db       Fred    Guerra                    Schmitt-Jones
# 99     c23d1D9EE8DEB0A     Yvonne    Farmer               Fitzgerald-Harrell
# 100    2354a0E336A91A1   Clarence    Haynes               Le, Nash and Cross
#
#                     City                     Country                 Phone 1  \
# Index
# 1           East Leonard                       Chile            229.077.5154
# 2      East Jimmychester                    Djibouti              5153435776
# 3          Isabelborough          Dominican Republic                   -1199
# 4             Bensonview          Dominican Republic  001-808-617-6467x12895
# 5         West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
# ...                  ...                         ...                     ...
# 96          East Richard                      Guyana     (188)169-1674x58692
# 97          New Bradview                   Sri Lanka                   -3769
# 98            Ortegaland             Solomon Islands    +1-753-067-8419x7170
# 99       Lake Elijahview                       Aruba           (530)311-9786
# 100            Judymouth                    Honduras           (753)813-6941
#
#                       Phone 2                           Email  \
# Index
# 1            397.884.0519x718        zunigavanessa@smith.info
# 2            686-620-1820x944                 vmata@colon.com
# 3         (496)978-3969x58947             beckycarr@hogan.com
# 4                       -9892     stanleyblackwell@benson.org
# 5       001-199-446-3860x3486         colinalvarado@miles.net
# ...                       ...                             ...
# 96       001-841-293-3519x614                hhart@jensen.com
# 97               605.413.3198               vkemp@ferrell.com
# 98      +1-632-666-7507x92121                swagner@kane.org
# 99     001-869-452-0943x12424  mccarthystephen@horn-green.biz
# 100              783.639.1472          colleen91@faulkner.biz
#
#       Subscription Date                            Website
# Index
# 1            2020-08-24         http://www.stephenson.com/
# 2            2021-04-23              http://www.hobbs.com/
# 3            2020-03-25           http://www.lawrence.com/
# 4            2020-06-02         http://www.good-lyons.com/
# 5            2021-04-17        https://goodwin-ingram.com/
# ...                 ...                                ...
# 96           2022-01-30            http://hayes-perez.com/
# 97           2021-07-10         https://novak-allison.com/
# 98           2021-09-18              https://www.ross.com/
# 99           2021-08-11               http://watkins.info/
# 100          2020-03-11  http://www.hatfield-saunders.net/
#
# [100 rows x 11 columns]

# %%
df6 = df.fillna(method='ffill', axis='columns')
df6.head()
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_5348\3255674045.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df6 = df.fillna(method='ffill', axis='columns')
#            Customer Id First Name Last Name                          Company  \
# Index
# 1      DD37Cf93aecA6Dc     Sheryl    Baxter                  Rasmussen Group
# 2      1Ef7b82A4CAAD10    Preston    Lozano                           Lozano
# 3      6F94879bDAfE5a6        Roy     Berry                    Murillo-Perry
# 4      5Cef8BFA16c5e3c      Linda     Linda  Dominguez, Mcmillan and Donovan
# 5      053d585Ab6b3159     Joanna    Bender         Martin, Lang and Andrade
#
#                     City                     Country                 Phone 1  \
# Index
# 1           East Leonard                       Chile            229.077.5154
# 2      East Jimmychester                    Djibouti              5153435776
# 3          Isabelborough               Isabelborough                   -1199
# 4             Bensonview          Dominican Republic  001-808-617-6467x12895
# 5         West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                      Phone 2                        Email  \
# Index
# 1           397.884.0519x718     zunigavanessa@smith.info
# 2           686-620-1820x944              vmata@colon.com
# 3        (496)978-3969x58947          beckycarr@hogan.com
# 4                      -9892  stanleyblackwell@benson.org
# 5      001-199-446-3860x3486      colinalvarado@miles.net
#
#          Subscription Date                      Website
# Index
# 1      2020-08-24 00:00:00   http://www.stephenson.com/
# 2      2021-04-23 00:00:00        http://www.hobbs.com/
# 3      2020-03-25 00:00:00     http://www.lawrence.com/
# 4      2020-06-02 00:00:00   http://www.good-lyons.com/
# 5      2021-04-17 00:00:00  https://goodwin-ingram.com/

# %%
df7 = df.dropna()
df7.head()
# Out:
#            Customer Id First Name Last Name                       Company  \
# Index
# 1      DD37Cf93aecA6Dc     Sheryl    Baxter               Rasmussen Group
# 5      053d585Ab6b3159     Joanna    Bender      Martin, Lang and Andrade
# 6      2d08FB17EE273F4      Aimee     Downs                  Steele Group
# 8      0e04AFde9f225dE      Brett    Mullen  Sanford, Davenport and Giles
# 9      C2dE4dEEc489ae0     Sheryl    Meyers                Browning-Simon
#
#                  City                     Country                 Phone 1  \
# Index
# 1        East Leonard                       Chile            229.077.5154
# 5      West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
# 6       Chavezborough      Bosnia and Herzegovina     (283)437-3886x88321
# 8             Kimport                    Bulgaria    001-583-352-7197x297
# 9        Robersonstad                      Cyprus       854-138-4911x5772
#
#                      Phone 2                     Email Subscription Date  \
# Index
# 1           397.884.0519x718  zunigavanessa@smith.info        2020-08-24
# 5      001-199-446-3860x3486   colinalvarado@miles.net        2021-04-17
# 6               999-728-1637       louis27@gilbert.com        2020-02-25
# 8           001-333-145-0369           asnow@colon.com        2021-04-12
# 9        +1-448-910-2276x729   mariokhan@ryan-pope.org        2020-01-13
#
#                            Website
# Index
# 1       http://www.stephenson.com/
# 5      https://goodwin-ingram.com/
# 6           http://www.berger.net/
# 8      https://hammond-ramsey.com/
# 9         https://www.bullock.net/
