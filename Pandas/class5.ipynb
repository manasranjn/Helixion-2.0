# %%
import pandas as pd
import numpy as np
df = pd.read_csv("customers-100.csv")
df.head(10)
# Out:
#    Index      Customer Id First Name  Last Name                       Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter               Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston     Lozano                           NaN
# 2    NaN              NaN        NaN        NaN                           NaN
# 3    NaN              NaN        NaN        NaN                           NaN
# 4    5.0  053d585Ab6b3159     Joanna        NaN      Martin, Lang and Andrade
# 5    NaN              NaN        NaN        NaN                           NaN
# 6    7.0  EA4d384DfDbBf77     Darren        NaN  Lester, Woodard and Mitchell
# 7    8.0  0e04AFde9f225dE      Brett     Mullen  Sanford, Davenport and Giles
# 8    9.0  C2dE4dEEc489ae0     Sheryl     Meyers                Browning-Simon
# 9   10.0  8C2811a503C7c5a   Michelle  Gallagher                  Beck-Hendrix
#
#                 City                     Country                 Phone 1  \
# ...

# %%
df2 = df.dropna(thresh=1)
df2
# Out:
#     Index      Customer Id First Name Last Name                   Company  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter           Rasmussen Group
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2     NaN              NaN        NaN       NaN                       NaN
# 4     5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
# 5     NaN              NaN        NaN       NaN                       NaN
# ..    ...              ...        ...       ...                       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer                 Carey LLC
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson     Ware, Burns and Oneal
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra             Schmitt-Jones
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer        Fitzgerald-Harrell
# 99  100.0  2354a0E336A91A1   Clarence    Haynes        Le, Nash and Cross
#
#                  City                     Country                 Phone 1  \
# ...

# %%
df3 = df.dropna(thresh=2)
df3.head()
# Out:
#    Index      Customer Id First Name Last Name                       Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl    Baxter               Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano                           NaN
# 4    5.0  053d585Ab6b3159     Joanna       NaN      Martin, Lang and Andrade
# 5    NaN              NaN        NaN       NaN                           NaN
# 6    7.0  EA4d384DfDbBf77     Darren       NaN  Lester, Woodard and Mitchell
#
#                 City                     Country                 Phone 1  \
# 0                NaN                       Chile                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
# 5                NaN                         NaN     (283)437-3886x88321
# 6           Lake Ana                         NaN      (496)452-6181x3291
#
# ...

# %%
df2 = pd.DataFrame({
    'day': ['1/1/2017', '1/2/2017', '1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})
df
# Out:
#     Index      Customer Id First Name Last Name                   Company  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter           Rasmussen Group
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2     NaN              NaN        NaN       NaN                       NaN
# 3     NaN              NaN        NaN       NaN                       NaN
# 4     5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
# ..    ...              ...        ...       ...                       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer                 Carey LLC
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson     Ware, Burns and Oneal
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra             Schmitt-Jones
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer        Fitzgerald-Harrell
# 99  100.0  2354a0E336A91A1   Clarence    Haynes        Le, Nash and Cross
#
#                  City                     Country                 Phone 1  \
# ...

# %%
type(df2['day'][0])
# Out:
# str

# %%
date = pd.date_range("09-10-2025", "09-20-2025")
date
# Out:
# DatetimeIndex(['2025-09-10', '2025-09-11', '2025-09-12', '2025-09-13',
#                '2025-09-14', '2025-09-15', '2025-09-16', '2025-09-17',
#                '2025-09-18', '2025-09-19', '2025-09-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
df3 = df.replace("Chile", "Hi")
df3.head()
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl    Baxter           Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2    NaN              NaN        NaN       NaN                       NaN
# 3    NaN              NaN        NaN       NaN                       NaN
# 4    5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0                NaN                          Hi                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# 2                NaN                         NaN                     NaN
# 3                NaN                         NaN                     NaN
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                  Phone 2                     Email Subscription Date  \
# ...

# %%
df3 = df.replace("Chile", np.nan)
df3.head()
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl    Baxter           Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2    NaN              NaN        NaN       NaN                       NaN
# 3    NaN              NaN        NaN       NaN                       NaN
# 4    5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0                NaN                         NaN                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# 2                NaN                         NaN                     NaN
# 3                NaN                         NaN                     NaN
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                  Phone 2                     Email Subscription Date  \
# ...

# %%
df3 = df.replace(["Chile", "Sheryl","Preston"], "New Value")
df3.head()
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0    1.0  DD37Cf93aecA6Dc  New Value    Baxter           Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10  New Value    Lozano                       NaN
# 2    NaN              NaN        NaN       NaN                       NaN
# 3    NaN              NaN        NaN       NaN                       NaN
# 4    5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0                NaN                   New Value                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# 2                NaN                         NaN                     NaN
# 3                NaN                         NaN                     NaN
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                  Phone 2                     Email Subscription Date  \
# ...

# %%
df
# Out:
#     Index      Customer Id First Name Last Name                   Company  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter           Rasmussen Group
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2     NaN              NaN        NaN       NaN                       NaN
# 3     NaN              NaN        NaN       NaN                       NaN
# 4     5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
# ..    ...              ...        ...       ...                       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer                 Carey LLC
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson     Ware, Burns and Oneal
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra             Schmitt-Jones
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer        Fitzgerald-Harrell
# 99  100.0  2354a0E336A91A1   Clarence    Haynes        Le, Nash and Cross
#
#                  City                     Country                 Phone 1  \
# ...

# %%
df3 = df.replace({
    "First Name": "Sheryl",
    "Country": "Chile"}, "New Value")
df3.head()
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0    1.0  DD37Cf93aecA6Dc  New Value    Baxter           Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2    NaN              NaN        NaN       NaN                       NaN
# 3    NaN              NaN        NaN       NaN                       NaN
# 4    5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0                NaN                   New Value                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# 2                NaN                         NaN                     NaN
# 3                NaN                         NaN                     NaN
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                  Phone 2                     Email Subscription Date  \
# ...

# %%
df3 = df.replace({
    "Baxter": "Value 1",
    "053d585Ab6b3159": "New ID"})
df3.head()
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl   Value 1           Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10    Preston    Lozano                       NaN
# 2    NaN              NaN        NaN       NaN                       NaN
# 3    NaN              NaN        NaN       NaN                       NaN
# 4    5.0           New ID     Joanna       NaN  Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0                NaN                       Chile                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# 2                NaN                         NaN                     NaN
# 3                NaN                         NaN                     NaN
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                  Phone 2                     Email Subscription Date  \
# ...

# %%
df3 = df.replace({'First Name': '[A-Za-z]'}, " ",
					regex= True)
df3
# Out:
#     Index      Customer Id First Name Last Name                   Company  \
# 0     1.0  DD37Cf93aecA6Dc               Baxter           Rasmussen Group
# 1     2.0  1Ef7b82A4CAAD10               Lozano                       NaN
# 2     NaN              NaN        NaN       NaN                       NaN
# 3     NaN              NaN        NaN       NaN                       NaN
# 4     5.0  053d585Ab6b3159                  NaN  Martin, Lang and Andrade
# ..    ...              ...        ...       ...                       ...
# 95   96.0  cb8E23e48d22Eae                Greer                 Carey LLC
# 96   97.0  CeD220bdAaCfaDf             Atkinson     Ware, Burns and Oneal
# 97   98.0  28CDbC0dFe4b1Db               Guerra             Schmitt-Jones
# 98   99.0  c23d1D9EE8DEB0A               Farmer        Fitzgerald-Harrell
# 99  100.0  2354a0E336A91A1               Haynes        Le, Nash and Cross
#
#                  City                     Country                 Phone 1  \
# ...

# %%
df3 = df.replace(["Chile", "Sheryl","Preston"], [1,2,3])
df3.head()
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0    1.0  DD37Cf93aecA6Dc          2    Baxter           Rasmussen Group
# 1    2.0  1Ef7b82A4CAAD10          3    Lozano                       NaN
# 2    NaN              NaN        NaN       NaN                       NaN
# 3    NaN              NaN        NaN       NaN                       NaN
# 4    5.0  053d585Ab6b3159     Joanna       NaN  Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0                NaN                           1                     NaN
# 1  East Jimmychester                    Djibouti              5153435776
# 2                NaN                         NaN                     NaN
# 3                NaN                         NaN                     NaN
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                  Phone 2                     Email Subscription Date  \
# ...
