# %%
import pandas as pd

df = pd.read_csv("customers-100.csv")
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df = pd.read_excel("file_example.xls")
df
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
df = pd.read_excel("file_example.xls", "Sheet2")
df
# Out:
#        Name  Gender        Country  Age    Id
# 0     Dulce  Female  United States   32  1562
# 1      Mara  Female  Great Britain   25  1582
# 2    Philip    Male         France   36  2587
# 3  Kathleen  Female  United States   25  3549
# 4   Nereida  Female  United States   58  2468
# 5    Gaston    Male  United States   24  2554
# 6      Etta  Female  Great Britain   56  3598
# 7   Earlean  Female  United States   27  2456
# 8  Vincenza  Female  United States   40  6548

# %%
data = {
    'Col1' : [1,2,3,4,5],
    'Col2' : ["A","B","C","D","E"]}
df2 = pd.DataFrame(data)
df2
# Out:
#    Col1 Col2
# 0     1    A
# 1     2    B
# 2     3    C
# 3     4    D
# 4     5    E

# %%
tuppleData = [(1, "Sumit", 21),
              (2, "Anshuman", 26),
              (3, "Saurav", 22)]
df3 = pd.DataFrame(tuppleData, columns=["S.N", "Name", "Age"])
df3
# Out:
#    S.N      Name  Age
# 0    1     Sumit   21
# 1    2  Anshuman   26
# 2    3    Saurav   22

# %%
listDict = [{ 'Name' : "Sumit", 'Age': 21, 'Course': "B.Tech"},
            { 'Name' : "Anshuman", 'Age': 26, 'Course': "B.Tech"},
            { 'Name' : "Saurav", 'Age': 22, 'Course': "B.Tech"}]
df4 = pd.DataFrame(listDict)
df4
# Out:
#        Name  Age  Course
# 0     Sumit   21  B.Tech
# 1  Anshuman   26  B.Tech
# 2    Saurav   22  B.Tech

# %% [markdown]
# # Reading and Writing CSV File

# %%
df = pd.read_csv("customers-100.csv")
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
df.head(10)
# Out:
#    Index      Customer Id First Name  Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1      2  1Ef7b82A4CAAD10    Preston     Lozano
# 2      3  6F94879bDAfE5a6        Roy      Berry
# 3      4  5Cef8BFA16c5e3c      Linda      Olsen
# 4      5  053d585Ab6b3159     Joanna     Bender
# 5      6  2d08FB17EE273F4      Aimee      Downs
# 6      7  EA4d384DfDbBf77     Darren       Peck
# 7      8  0e04AFde9f225dE      Brett     Mullen
# 8      9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9     10  8C2811a503C7c5a   Michelle  Gallagher
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
# 5                     Steele Group      Chavezborough
# ...

# %%
df = pd.read_csv("customers-100.csv", skiprows=5)
df
# Out:
#       5  053d585Ab6b3159    Joanna     Bender      Martin, Lang and Andrade  \
# 0     6  2d08FB17EE273F4     Aimee      Downs                  Steele Group
# 1     7  EA4d384DfDbBf77    Darren       Peck  Lester, Woodard and Mitchell
# 2     8  0e04AFde9f225dE     Brett     Mullen  Sanford, Davenport and Giles
# 3     9  C2dE4dEEc489ae0    Sheryl     Meyers                Browning-Simon
# 4    10  8C2811a503C7c5a  Michelle  Gallagher                  Beck-Hendrix
# ..  ...              ...       ...        ...                           ...
# 90   96  cb8E23e48d22Eae      Karl      Greer                     Carey LLC
# 91   97  CeD220bdAaCfaDf      Lynn   Atkinson         Ware, Burns and Oneal
# 92   98  28CDbC0dFe4b1Db      Fred     Guerra                 Schmitt-Jones
# 93   99  c23d1D9EE8DEB0A    Yvonne     Farmer            Fitzgerald-Harrell
# 94  100  2354a0E336A91A1  Clarence     Haynes            Le, Nash and Cross
#
# ...

# %%
df = pd.read_csv("customers-100.csv", skiprows=1)
df
# Out:
#       1  DD37Cf93aecA6Dc    Sheryl    Baxter                  Rasmussen Group  \
# 0     2  1Ef7b82A4CAAD10   Preston    Lozano                      Vega-Gentry
# 1     3  6F94879bDAfE5a6       Roy     Berry                    Murillo-Perry
# 2     4  5Cef8BFA16c5e3c     Linda     Olsen  Dominguez, Mcmillan and Donovan
# 3     5  053d585Ab6b3159    Joanna    Bender         Martin, Lang and Andrade
# 4     6  2d08FB17EE273F4     Aimee     Downs                     Steele Group
# ..  ...              ...       ...       ...                              ...
# 94   96  cb8E23e48d22Eae      Karl     Greer                        Carey LLC
# 95   97  CeD220bdAaCfaDf      Lynn  Atkinson            Ware, Burns and Oneal
# 96   98  28CDbC0dFe4b1Db      Fred    Guerra                    Schmitt-Jones
# 97   99  c23d1D9EE8DEB0A    Yvonne    Farmer               Fitzgerald-Harrell
# 98  100  2354a0E336A91A1  Clarence    Haynes               Le, Nash and Cross
#
# ...

# %%
df = pd.read_csv("customers-100.csv", header=15)
df
# Out:
#      15  6fEaA1b7cab7B6C     Faith      Lutz         Carter-Hancock  \
# 0    16  8cad0b4CBceaeec   Miranda   Beasley     Singleton and Sons
# 1    17  a5DC21AE3a21eaA  Caroline     Foley        Winters-Mendoza
# 2    18  F8Aa9d6DfcBeeF8      Greg      Mata          Valentine LLC
# 3    19  F160f5Db3EfE973  Clifford  Jacobson              Simon LLC
# 4    20  0F60FF3DdCd7aB0    Joanna      Kirk         Mays-Mccormick
# ..  ...              ...       ...       ...                    ...
# 80   96  cb8E23e48d22Eae      Karl     Greer              Carey LLC
# 81   97  CeD220bdAaCfaDf      Lynn  Atkinson  Ware, Burns and Oneal
# 82   98  28CDbC0dFe4b1Db      Fred    Guerra          Schmitt-Jones
# 83   99  c23d1D9EE8DEB0A    Yvonne    Farmer     Fitzgerald-Harrell
# 84  100  2354a0E336A91A1  Clarence    Haynes     Le, Nash and Cross
#
#             Burchbury                                     Singapore  \
# 0        Desireeshire                                          Oman
# ...

# %%
df = pd.read_csv("customers-100.csv", header=None)
df
# Out:
#         0                1           2          3   \
# 0    Index      Customer Id  First Name  Last Name
# 1        1  DD37Cf93aecA6Dc      Sheryl     Baxter
# 2        2  1Ef7b82A4CAAD10     Preston     Lozano
# 3        3  6F94879bDAfE5a6         Roy      Berry
# 4        4  5Cef8BFA16c5e3c       Linda      Olsen
# ..     ...              ...         ...        ...
# 96      96  cb8E23e48d22Eae        Karl      Greer
# 97      97  CeD220bdAaCfaDf        Lynn   Atkinson
# 98      98  28CDbC0dFe4b1Db        Fred     Guerra
# 99      99  c23d1D9EE8DEB0A      Yvonne     Farmer
# 100    100  2354a0E336A91A1    Clarence     Haynes
#
#                                   4                  5                    6   \
# 0                            Company               City              Country
# 1                    Rasmussen Group       East Leonard                Chile
# 2                        Vega-Gentry  East Jimmychester             Djibouti
# ...

# %%
df = pd.read_csv("customers-100.csv", header=None, names=["Col1", "Col2", "Col3", "Col4", "Col5", "Col6", "Col7", "Col8", "Col9", "Col10", "Col11"])
df
# Out:
#                   Col1        Col2       Col3  \
# Index      Customer Id  First Name  Last Name
# 1      DD37Cf93aecA6Dc      Sheryl     Baxter
# 2      1Ef7b82A4CAAD10     Preston     Lozano
# 3      6F94879bDAfE5a6         Roy      Berry
# 4      5Cef8BFA16c5e3c       Linda      Olsen
# ...                ...         ...        ...
# 96     cb8E23e48d22Eae        Karl      Greer
# 97     CeD220bdAaCfaDf        Lynn   Atkinson
# 98     28CDbC0dFe4b1Db        Fred     Guerra
# 99     c23d1D9EE8DEB0A      Yvonne     Farmer
# 100    2354a0E336A91A1    Clarence     Haynes
#
#                                   Col4               Col5  \
# Index                          Company               City
# 1                      Rasmussen Group       East Leonard
# 2                          Vega-Gentry  East Jimmychester
# 3                        Murillo-Perry      Isabelborough
# 4      Dominguez, Mcmillan and Donovan         Bensonview
# ...

# %%
df = pd.read_csv("customers-100.csv", nrows=5)
df
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
df = pd.read_csv("customers-100.csv", na_values=["Linda", "Chile"])
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c        NaN     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df = pd.read_csv("customers-100.csv", na_values=["Linda", "Chile", "Baxter"])
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl       NaN
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c        NaN     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df = pd.read_csv("customers-100.csv", na_values={
        'First Name': ["Linda"],
        'Company': ["Rasmussen Group", "Vega-Gentry"]}
    )
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c        NaN     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                               NaN       East Leonard
# 1                               NaN  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.to_csv("newFile.csv")

# %%
df.to_csv("newFile.csv", index=False)

# %%
df.to_csv("newFile.csv", columns=["First Name","Company","Email"], index=False)

# %%
df.to_csv("newFile.csv", header=False)
